# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import re
import os.path
from os import path

# %% [markdown]
# ## Automate tournament check

# %%
# Change this for the stat you want
stat_id = '120'

tournament_list_2020 = []
tournament_list_2019 = []
tournament_list_2018 = []
tournament_list_2017 = []
tournament_list_2016 = []
tournament_list_2015 = []
tournament_list_2014 = []
tournament_list_2013 = []
tournament_list_2012 = []
tournament_list_2011 = []
tournament_list_2010 = []
tournament_list_2009 = []
tournament_list_2008 = []
tournament_list_2007 = []
tournament_list_2006 = []
tournament_list_2005 = []
tournament_list_2004 = []
tournament_list_2003 = []
tournament_list_2002 = []
tournament_list_2001 = []
tournament_list_2000 = []
tournament_list_1999 = []
tournament_list_1998 = []
tournament_list_1997 = []
tournament_list_1996 = []
tournament_list_1995 = []
tournament_list_1994 = []
tournament_list_1993 = []
tournament_list_1992 = []
tournament_list_1991 = []
tournament_list_1990 = []
tournament_list_1989 = []
tournament_list_1988 = []
tournament_list_1987 = []
tournament_list_1986 = []
tournament_list_1985 = []
tournament_list_1984 = []
tournament_list_1983 = []
tournament_list_1982 = []
tournament_list_1981 = []
tournament_list_1980 = []

for year in range(1980, 2021):
    if year == 1980:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1980.append([option['value'] for option in container_list])
        tournament_list_1980 = tournament_list_1980[0]
        
    elif year == 1981:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1981.append([option['value'] for option in container_list])
        tournament_list_1981 = tournament_list_1981[0]

    elif year == 1982:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1982.append([option['value'] for option in container_list])
        tournament_list_1982 = tournament_list_1982[0]

    elif year == 1983:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1983.append([option['value'] for option in container_list])
        tournament_list_1983 = tournament_list_1983[0]

    elif year == 1984:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1984.append([option['value'] for option in container_list])
        tournament_list_1984 = tournament_list_1984[0]

    elif year == 1985:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1985.append([option['value'] for option in container_list])
        tournament_list_1985 = tournament_list_1985[0]
 
    elif year == 1986:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1986.append([option['value'] for option in container_list])
        tournament_list_1986 = tournament_list_1986[0]

    elif year == 1987:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1987.append([option['value'] for option in container_list])
        tournament_list_1987 = tournament_list_1987[0]

    elif year == 1988:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1988.append([option['value'] for option in container_list])
        tournament_list_1988 = tournament_list_1988[0]
 
    elif year == 1989:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1989.append([option['value'] for option in container_list])
        tournament_list_1989 = tournament_list_1989[0]

    elif year == 1990:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1990.append([option['value'] for option in container_list])
        tournament_list_1990 = tournament_list_1990[0]

    elif year == 1991:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1991.append([option['value'] for option in container_list])
        tournament_list_1991 = tournament_list_1991[0]

    elif year == 1992:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1992.append([option['value'] for option in container_list])
        tournament_list_1992 = tournament_list_1992[0]

    elif year == 1993:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1993.append([option['value'] for option in container_list])
        tournament_list_1993 = tournament_list_1993[0]

    elif year == 1994:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1994.append([option['value'] for option in container_list])
        tournament_list_1994 = tournament_list_1994[0]

    elif year == 1995:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1995.append([option['value'] for option in container_list])
        tournament_list_1995 = tournament_list_1995[0]

    elif year == 1996:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1996.append([option['value'] for option in container_list])
        tournament_list_1996 = tournament_list_1996[0]

    elif year == 1997:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1997.append([option['value'] for option in container_list])
        tournament_list_1997 = tournament_list_1997[0]

    elif year == 1998:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1998.append([option['value'] for option in container_list])
        tournament_list_1998 = tournament_list_1998[0]

    elif year == 1999:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_1999.append([option['value'] for option in container_list])
        tournament_list_1999 = tournament_list_1999[0]

    elif year == 2000:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2000.append([option['value'] for option in container_list])
        tournament_list_2000 = tournament_list_2000[0]

    elif year == 2001:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2001.append([option['value'] for option in container_list])
        tournament_list_2001 = tournament_list_2001[0]

    elif year == 2002:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2002.append([option['value'] for option in container_list])
        tournament_list_2002 = tournament_list_2002[0]

    elif year == 2003:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2003.append([option['value'] for option in container_list])
        tournament_list_2003 = tournament_list_2003[0]

    elif year == 2004:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2004.append([option['value'] for option in container_list])
        tournament_list_2004 = tournament_list_2004[0]

    elif year == 2005:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2005.append([option['value'] for option in container_list])
        tournament_list_2005 = tournament_list_2005[0]

    elif year == 2006:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2006.append([option['value'] for option in container_list])
        tournament_list_2006 = tournament_list_2006[0]

    elif year == 2007:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2007.append([option['value'] for option in container_list])
        tournament_list_2007 = tournament_list_2007[0]

    elif year == 2008:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2008.append([option['value'] for option in container_list])
        tournament_list_2008 = tournament_list_2008[0]

    elif year == 2008:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2008.append([option['value'] for option in container_list])
        tournament_list_2008 = tournament_list_2008[0]
        
    elif year == 2009:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2009.append([option['value'] for option in container_list])
        tournament_list_2009 = tournament_list_2009[0]

    elif year == 2010:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2010.append([option['value'] for option in container_list])
        tournament_list_2010 = tournament_list_2010[0]
        
    elif year == 2011:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2011.append([option['value'] for option in container_list])
        tournament_list_2011 = tournament_list_2011[0]
        
    elif year == 2012:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2012.append([option['value'] for option in container_list])
        tournament_list_2012 = tournament_list_2012[0]
        
    elif year == 2013:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2013.append([option['value'] for option in container_list])
        tournament_list_2013 = tournament_list_2013[0]
        
    elif year == 2014:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2014.append([option['value'] for option in container_list])
        tournament_list_2014 = tournament_list_2014[0]
        
    elif year == 2015:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2015.append([option['value'] for option in container_list])
        tournament_list_2015 = tournament_list_2015[0]
        
    elif year == 2016:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2016.append([option['value'] for option in container_list])
        tournament_list_2016 = tournament_list_2016[0]
        
    elif year == 2017:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2017.append([option['value'] for option in container_list])
        tournament_list_2017 = tournament_list_2017[0]
        
    elif year == 2018:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2018.append([option['value'] for option in container_list])
        tournament_list_2018 = tournament_list_2018[0]

    elif year == 2019:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2019.append([option['value'] for option in container_list])
        tournament_list_2019 = tournament_list_2019[0]
        
    elif year == 2020:
        print('Processing year', year)
        url = "https://www.pgatour.com/content/pgatour/stats/stat.{stat_id}.y{year}.html".format(stat_id=stat_id, year=year)
        html = urlopen(url)
        soup = BeautifulSoup(html)
        container = soup.findAll("div", {"class": "with-chevron"})[2]    
        container_list = container.findAll("option")

        tournament_list_2020.append([option['value'] for option in container_list])
        tournament_list_2020 = tournament_list_2020[0]
# Out:
# Processing year 1980
# Processing year 1981
# Processing year 1982
# Processing year 1983
# Processing year 1984
# Processing year 1985
# Processing year 1986
# Processing year 1987
# Processing year 1988
# Processing year 1989
# Processing year 1990
# Processing year 1991
# Processing year 1992
# Processing year 1993
# Processing year 1994
# Processing year 1995
# Processing year 1996
# Processing year 1997
# Processing year 1998
# Processing year 1999
# Processing year 2000
# Processing year 2001
# Processing year 2002
# Processing year 2003
# Processing year 2004
# Processing year 2005
# Processing year 2006
# Processing year 2007
# Processing year 2008
# Processing year 2009
# Processing year 2010
# Processing year 2011
# Processing year 2012
# Processing year 2013
# Processing year 2014
# Processing year 2015
# Processing year 2016
# Processing year 2017
# Processing year 2018
# Processing year 2019
# Processing year 2020

# %% [markdown]
# ## Create dataframe for later use

# %%
frames = [tournament_list_1980,
          tournament_list_1981,
          tournament_list_1982,
          tournament_list_1983,
          tournament_list_1984,
          tournament_list_1985,
          tournament_list_1986,
          tournament_list_1987,
          tournament_list_1988,
          tournament_list_1989,
          tournament_list_1990,
          tournament_list_1991,
          tournament_list_1992,
          tournament_list_1993,
          tournament_list_1994,
          tournament_list_1995,
          tournament_list_1996,
          tournament_list_1997,
          tournament_list_1998,
          tournament_list_1999,
          tournament_list_2000,
          tournament_list_2001,
          tournament_list_2002,
          tournament_list_2003,
          tournament_list_2004,
          tournament_list_2005,
          tournament_list_2006,
          tournament_list_2007,
          tournament_list_2008,
          tournament_list_2009,
          tournament_list_2010,
          tournament_list_2011,
          tournament_list_2012,
          tournament_list_2013,
          tournament_list_2014,
          tournament_list_2015,
          tournament_list_2016,
          tournament_list_2017,
          tournament_list_2018,
          tournament_list_2019,
          tournament_list_2020]

# %%
# dictionary of lists  
dict = {'1980': tournament_list_1980,
          '1981' : tournament_list_1981,
          '1982' : tournament_list_1982,
          '1983' : tournament_list_1983,
          '1984' : tournament_list_1984,
          '1985' : tournament_list_1985,
          '1986' : tournament_list_1986,
          '1987' : tournament_list_1987,
          '1988' : tournament_list_1988,
          '1989' : tournament_list_1989,
          '1990' : tournament_list_1990,
          '1991' : tournament_list_1991,
          '1992' : tournament_list_1992,
          '1993' : tournament_list_1993,
          '1994' : tournament_list_1994,
          '1995' : tournament_list_1995,
          '1996' : tournament_list_1996,
          '1997' : tournament_list_1997,
          '1998' : tournament_list_1998,
          '1999' : tournament_list_1999,
          '2000' : tournament_list_2000,
          '2001' : tournament_list_2001,
          '2002' : tournament_list_2002,
          '2003' : tournament_list_2003,
          '2004' : tournament_list_2004,
          '2005' : tournament_list_2005,
          '2006' : tournament_list_2006,
          '2007' : tournament_list_2007,
          '2008' : tournament_list_2008,
          '2009' : tournament_list_2009,
          '2010' : tournament_list_2010,
          '2011' : tournament_list_2011,
          '2012' : tournament_list_2012,
          '2013' : tournament_list_2013,
          '2014' : tournament_list_2014,
          '2015' : tournament_list_2015,
          '2016' : tournament_list_2016,
          '2017' : tournament_list_2017,
          '2018' : tournament_list_2018,
          '2019' : tournament_list_2019,
          '2020' : tournament_list_2020,
       }  
    
df = pd.DataFrame.from_dict(dict, orient='index').T

# %%
df.head()
# Out:
#    1980  1981  1982  1983  1984  1985  1986  1987  1988  1989  ...  2011  \
# 0  t044  t044  t045  t044  t044  t001  t057  t495  t060  t060  ...  t045
# 1  t040  t040  t044  t045  t045  t044  t001  t057  t057  t495  ...  t493
# 2  t031  t041  t042  t040  t040  t045  t041  t060  t001  t045  ...  t464
# 3  t041  t039  t041  t041  t041  t040  t045  t001  t045  t041  ...  t047
# 4  t039  t042  t040  t042  t042  t041  t044  t045  t495  t057  ...  t060
#
#    2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0  t045  t060  t060  t060  t060  t060  t060  t060  t007
# 1  t493  t028  t028  t028  t028  t028  t028  t028  t005
# 2  t464  t505  t505  t505  t505  t505  t505  t027  t003
# 3  t047  t027  t027  t027  t027  t027  t027  t013  t004
# 4  t060  t013  t013  t013  t013  t013  t013  t472  t002
#
# [5 rows x 41 columns]

# %%
# Export dataframe
df.to_csv('/Users/nicholasbeaudoin/Desktop/Projects/PGA Tour Project/data/stat_id_{}_tournaments.csv'.format(stat_id), index=False)

# %%
# !pwd
# Out:
# /Users/nicholasbeaudoin/Desktop/Projects/PGA Tour Project/PGA-Tour-Analytics/notebooks
