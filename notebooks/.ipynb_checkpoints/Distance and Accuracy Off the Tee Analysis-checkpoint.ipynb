# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(20, 10)})
sns.set_context("poster", rc={"lines.linewidth": 5})

# %%
# !pwd
# Out:
# /Users/nicholasbeaudoin/Desktop/Projects/PGA Tour Project/PGA-Tour-Analytics/notebooks

# %% [markdown]
# ### Import data

# %%
df_dist = pd.read_csv('../../data/Off the tee_Driving Distance.csv')
df_acc = pd.read_csv('../../data/Off the tee_Driving Accuracy Percentage.csv')
df_fin = pd.read_csv('../../data/Finish_ing Average.csv')

# Drop first column
df_dist.drop('Unnamed: 0', axis = 1, inplace=True)
df_acc.drop('Unnamed: 0', axis = 1, inplace=True)
df_fin.drop('Unnamed: 0', axis = 1, inplace=True)

# %% [markdown]
# ### Merge data

# %%
df_dist.head()
# Out:
#          PLAYER NAME  ROUNDS   AVG. TOTAL DISTANCE  TOTAL DRIVES  YEAR  \
# 0           Dan Pohl       4  282.6          2,261             8  1980
# 1    Stanton Altgelt       4  280.1          2,241             8  1980
# 2      Gary Hallberg       4  276.9          2,215             8  1980
# 3  Dave Eichelberger       4  275.4          2,203             8  1980
# 4       George Cadle       4  275.3          2,202             8  1980
#
#        Tournament
# 0  Pensacola Open
# 1  Pensacola Open
# 2  Pensacola Open
# 3  Pensacola Open
# 4  Pensacola Open

# %%
df_acc.head()
# Out:
#       PLAYER NAME  ROUNDS      %  FAIRWAYS HIT  POSSIBLE FAIRWAYS  YEAR  \
# 0       Mike Reid       4  75.00            42                 56  1980
# 1   Miller Barber       4  71.43            40                 56  1980
# 2      Don Pooley       4  66.07            37                 56  1980
# 3  Rik Massengale       4  66.07            37                 56  1980
# 4  Lonnie Nielsen       4  64.29            36                 56  1980
#
#        Tournament
# 0  Pensacola Open
# 1  Pensacola Open
# 2  Pensacola Open
# 3  Pensacola Open
# 4  Pensacola Open

# %%
df_fin.head()
# Out:
#          PLAYER NAME  ROUNDS    AVG  TOTAL STROKES TOTAL ADJUSTMENT  \
# 0     Dan Halldorson       4  68.75            275              NaN
# 1      Gary Hallberg       4  69.25            277              NaN
# 2      Mike Sullivan       4  69.25            277              NaN
# 3          Mike Gove       4  69.50            278              NaN
# 4  Dave Eichelberger       4  69.50            278              NaN
#
#    TOTAL ROUNDS  YEAR      Tournament  RANK THIS WEEK
# 0             4  1980  Pensacola Open               1
# 1             4  1980  Pensacola Open               2
# 2             4  1980  Pensacola Open               2
# 3             4  1980  Pensacola Open               4
# 4             4  1980  Pensacola Open               4

# %%
# Merge distance and accuracy on player, tournament and year
df = pd.merge(df_dist, df_acc, on=['PLAYER NAME', 'Tournament', 'YEAR'])
df.head()
# Out:
#          PLAYER NAME  ROUNDS_x   AVG. TOTAL DISTANCE  TOTAL DRIVES  YEAR  \
# 0           Dan Pohl         4  282.6          2,261             8  1980
# 1    Stanton Altgelt         4  280.1          2,241             8  1980
# 2      Gary Hallberg         4  276.9          2,215             8  1980
# 3  Dave Eichelberger         4  275.4          2,203             8  1980
# 4       George Cadle         4  275.3          2,202             8  1980
#
#        Tournament  ROUNDS_y      %  FAIRWAYS HIT  POSSIBLE FAIRWAYS
# 0  Pensacola Open         4  33.93            19                 56
# 1  Pensacola Open         4  42.86            24                 56
# 2  Pensacola Open         4  55.36            31                 56
# 3  Pensacola Open         4  50.00            28                 56
# 4  Pensacola Open         4  46.43            26                 56

# %%
# Merge df to df_fin
df = pd.merge(df, df_fin, on=['PLAYER NAME', 'Tournament', 'YEAR'])
df.head()
# Out:
#          PLAYER NAME  ROUNDS_x   AVG. TOTAL DISTANCE  TOTAL DRIVES  YEAR  \
# 0           Dan Pohl         4  282.6          2,261             8  1980
# 1    Stanton Altgelt         4  280.1          2,241             8  1980
# 2      Gary Hallberg         4  276.9          2,215             8  1980
# 3  Dave Eichelberger         4  275.4          2,203             8  1980
# 4       George Cadle         4  275.3          2,202             8  1980
#
#        Tournament  ROUNDS_y      %  FAIRWAYS HIT  POSSIBLE FAIRWAYS  ROUNDS  \
# 0  Pensacola Open         4  33.93            19                 56       4
# 1  Pensacola Open         4  42.86            24                 56       4
# 2  Pensacola Open         4  55.36            31                 56       4
# 3  Pensacola Open         4  50.00            28                 56       4
# 4  Pensacola Open         4  46.43            26                 56       4
#
#      AVG  TOTAL STROKES TOTAL ADJUSTMENT  TOTAL ROUNDS  RANK THIS WEEK
# 0  71.25            285              NaN             4              34
# 1  71.00            284              NaN             4              27
# 2  69.25            277              NaN             4               2
# 3  69.50            278              NaN             4               4
# 4  70.75            283              NaN             4              24

# %%
# Clean up the dataframe (drop columns)
df.drop(['ROUNDS', 'ROUNDS_x','ROUNDS_y', 'TOTAL ADJUSTMENT', 'AVG'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#          PLAYER NAME   AVG. TOTAL DISTANCE  TOTAL DRIVES  YEAR  \
# 0           Dan Pohl  282.6          2,261             8  1980
# 1    Stanton Altgelt  280.1          2,241             8  1980
# 2      Gary Hallberg  276.9          2,215             8  1980
# 3  Dave Eichelberger  275.4          2,203             8  1980
# 4       George Cadle  275.3          2,202             8  1980
#
#        Tournament      %  FAIRWAYS HIT  POSSIBLE FAIRWAYS  TOTAL STROKES  \
# 0  Pensacola Open  33.93            19                 56            285
# 1  Pensacola Open  42.86            24                 56            284
# 2  Pensacola Open  55.36            31                 56            277
# 3  Pensacola Open  50.00            28                 56            278
# 4  Pensacola Open  46.43            26                 56            283
#
#    TOTAL ROUNDS  RANK THIS WEEK
# 0             4              34
# 1             4              27
# 2             4               2
# 3             4               4
# 4             4              24

# %%
# Rename features
df.rename(columns={'AVG.':'DRIVING_DIST', 
                  '%':'DRIVING_ACC'}, inplace=True)

# %%
df.head()
# Out:
#          PLAYER NAME  DRIVING_DIST TOTAL DISTANCE  TOTAL DRIVES  YEAR  \
# 0           Dan Pohl         282.6          2,261             8  1980
# 1    Stanton Altgelt         280.1          2,241             8  1980
# 2      Gary Hallberg         276.9          2,215             8  1980
# 3  Dave Eichelberger         275.4          2,203             8  1980
# 4       George Cadle         275.3          2,202             8  1980
#
#        Tournament  DRIVING_ACC  FAIRWAYS HIT  POSSIBLE FAIRWAYS  \
# 0  Pensacola Open        33.93            19                 56
# 1  Pensacola Open        42.86            24                 56
# 2  Pensacola Open        55.36            31                 56
# 3  Pensacola Open        50.00            28                 56
# 4  Pensacola Open        46.43            26                 56
#
#    TOTAL STROKES  TOTAL ROUNDS  RANK THIS WEEK
# 0            285             4              34
# 1            284             4              27
# 2            277             4               2
# 3            278             4               4
# 4            283             4              24

# %%
# How many players?
len(df['PLAYER NAME'].unique())
# Out:
# 2187

# %% [markdown]
# ### Distance over time

# %%
year_avg_df = df.groupby('YEAR', as_index=False)['DRIVING_DIST'].mean()
        
sns.lineplot(data=year_avg_df, x='YEAR', y='DRIVING_DIST')
plt.title('Distance Since 1980', size=30)
plt.axvline(2000, color='red', alpha=0.2)

# %% [markdown]
# ### Accuracy over time

# %%
year_avg_df = df.groupby('YEAR', as_index=False)['DRIVING_ACC'].mean()
        
sns.lineplot(data=year_avg_df, x='YEAR', y='DRIVING_ACC')
plt.title('Distance Since 1980', size=30)
plt.axvline(2000, color='red', alpha=0.2)

# %% [markdown]
# ### Off tee: Distance and Accuracy

# %%
# Groupby for distance and accuracy
year_dist_df = df.groupby('YEAR', as_index=False)['DRIVING_DIST'].mean()
year_acc_df = df.groupby('YEAR', as_index=False)['DRIVING_ACC'].mean()

# Combine DFs
mini_df = year_dist_df.merge(year_acc_df)
mini_df.head()
# Out:
#    YEAR  DRIVING_DIST  DRIVING_ACC
# 0  1980    257.521122    63.830585
# 1  1981    259.963758    63.307169
# 2  1982    257.325528    64.181962
# 3  1983    259.427561    64.191745
# 4  1984    260.103681    64.409969

# %%
sns.set_style('whitegrid')

ax = sns.lineplot(data=mini_df, x='YEAR', y='DRIVING_DIST', color='green')
ax2 = ax.twinx()
sns.lineplot(data=mini_df, x='YEAR', y='DRIVING_ACC')

ax.legend(labels=['Distance'], loc='lower left')
ax2.legend(labels=['Accuracy'], loc='center left',)

ax.grid(False)
ax2.grid(False)

ax.set_ylabel('Distance')
ax2.set_ylabel('Accuracy')

plt.title('Off the Tee Since 1980', size=30)
plt.axvline(2000, color='red', alpha=0.2)


plt.show()

# %%
# Groupby player each year
player_dist_df = df.groupby(['PLAYER NAME', 'YEAR'], as_index=False)['DRIVING_DIST'].mean()
player_acc_df = df.groupby(['PLAYER NAME', 'YEAR'], as_index=False)['DRIVING_ACC'].mean()

# Combine DFs
player_df = player_dist_df.merge(player_acc_df)
player_df.head()
# Out:
#       PLAYER NAME  YEAR  DRIVING_DIST  DRIVING_ACC
# 0     A.J. Duncan  1988         283.5       58.930
# 1     A.J. Duncan  1990         264.1       44.640
# 2  A.J. McInerney  2018         298.5       50.000
# 3  Aaron Baddeley  2000         283.6       64.290
# 4  Aaron Baddeley  2001         273.3       54.465

# %%
sns.jointplot("DRIVING_DIST", "DRIVING_ACC", lowess=True, height=12, data=player_df, kind='reg', 
              scatter_kws={'alpha':0.15, "s": 50}, line_kws={'color': 'red'})
